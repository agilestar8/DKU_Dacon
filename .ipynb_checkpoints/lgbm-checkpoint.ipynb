# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import cross_val_score
from catboost import CatBoostClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
pd.options.display.max_columns = 50
plt.rcParams["figure.figsize"] = (20,12)

# %%
train = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\train.csv")
test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\test.csv")

# %%
alldata = pd.concat([train,test])
# alldata = alldata.drop(alldata[alldata["dered_g"] == -9999].index)
# alldata = alldata.drop(alldata[alldata["dered_i"] == -9999].index)
# alldata = alldata.drop(alldata[alldata["dered_z"] == -9999].index)
# alldata = alldata.drop(alldata[alldata["z"] == -9999].index)
alldata.describe()
# Out:
#                   id              u              g              r  \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean   199999.500000      19.853911      18.388891      17.736557
# std    115470.198175       1.947292      27.836731       1.468719
# min         0.000000     -17.687512  -17555.365606      -5.438650
# 25%     99999.750000      18.724761      17.475412      16.878248
# 50%    199999.500000      19.420835      18.141361      17.526730
# 75%    299999.250000      20.432632      19.074540      18.428941
# max    399999.000000      58.623328      94.359125      72.009662
#
#                    i              z       redshift        dered_u  \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean       17.200679      16.929940       0.058663      19.630089
# std        47.016128      52.287872       0.537570       1.923074
# min    -23955.817764  -23955.817764    -166.048260     -42.837530
# 25%        16.524128      16.288817       0.000035      18.565090
# 50%        17.151000      16.918373       0.047127      19.265195
# 75%        18.007443      17.729659       0.094629      20.198145
# max        50.164052    6976.392220      62.323343      30.889910
#
#              dered_g        dered_r        dered_i        dered_z  \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean       18.234426      17.616215      17.165439      16.869468
# std        15.926223       1.473616      22.436363      35.436536
# min     -9999.000000     -16.380230   -9999.000000   -9999.000000
# 25%        17.349170      16.787888      16.453717      16.233397
# 50%        18.022860      17.444390      17.088090      16.870060
# 75%        18.890170      18.292180      17.907530      17.655963
# max        30.952920      31.957200      32.016220      30.781270
#
#             nObserve        nDetect      airmass_u      airmass_g  \
# count  400000.000000  400000.000000  400000.000000  400000.000000
# mean        6.336150       6.142602       1.175802       1.176569
# std         8.879454       8.551472       0.116323       0.118092
# min         1.000000       1.000000       1.000059       1.000012
# 25%         1.000000       1.000000       1.088191       1.088428
# 50%         2.000000       2.000000       1.179350       1.179242
# 75%         5.000000       5.000000       1.227600       1.226032
# max        44.000000      42.000000       2.050775       2.080287
#
#            airmass_r      airmass_i      airmass_z          class
# count  400000.000000  400000.000000  400000.000000  320000.000000
# mean        1.175167       1.175467       1.176168       1.116322
# std         0.114748       0.115510       0.117182       0.923455
# min         1.000157       1.000105       1.000027       0.000000
# 25%         1.087747       1.087998       1.088278       0.000000
# 50%         1.179375       1.179381       1.179306       1.000000
# 75%         1.229272       1.228639       1.226807       2.000000
# max         2.022134       2.036329       2.065390       2.000000

# %%
# alldata[alldata["dered_g"] == -9999] # 1
# alldata[alldata["dered_i"] == -9999] # 2
# alldata[alldata["dered_z"] == -9999] # 2
# alldata[alldata["dered_z"] == -9999] # 2

# %%
# plt.figure(figsize = (20,12))
# sns.heatmap(train.corr(), annot = True, annot_kws = {"size" : 11}, linewidths = 1 )

# %% [markdown]
# 망원경에서 망원경으로 또는 밤에서 밤까지 절대교정과 관련된 불확실성을 줄이기 위해
#
# 천문학자들은 일반적으로 두 개의 서로 다른 필터 밴드 사이의 크기 차이로 정의되는 색상으로 작업한다.
#
# 두 개의 크기를 빼면 이러한 불확실성이 감소한다.
#
# 예를 들어, 위의 별 베가에 대한 관측은 벡터 4개의 숫자로 구성된다. [u-g, g-r, r-i, i-z]

# %%
alldata["u-g"] = alldata["u"]-alldata["g"]
alldata["g-r"] = alldata["g"]-alldata["r"]
alldata["r-i"] = alldata["r"]-alldata["i"]
alldata["i-z"] = alldata["i"]-alldata["z"]

alldata["dered_diff1"] = alldata["dered_u"]-alldata["dered_g"]
alldata["dered_diff2"] = alldata["dered_g"]-alldata["dered_r"]
alldata["dered_diff3"] = alldata["dered_r"]-alldata["dered_i"]
alldata["dered_diff4"] = alldata["dered_i"]-alldata["dered_z"]

# alldata['new'] = alldata["u"]-alldata["z"]



# alldata["minusOD"] = alldata["nObserve"] - alldata["nDetect"]   # 0.1560
# alldata["plusOD"] = alldata["nObserve"] + alldata["nDetect"]  # 0.1557

# alldata["diff_u"] = alldata["u-g"] - alldata["dered_diff1"]
# alldata["diff_g"] = alldata["g-r"] - alldata["dered_diff2"]
# alldata["diff_r"] = alldata["r-i"] - alldata["dered_diff3"]
# alldata["diff_i"] = alldata["i-z"] - alldata["dered_diff4"]

# alldata["diff1"] = alldata["u"] - alldata["dered_g"]
# alldata["diff2"] = alldata["g"] - alldata["dered_r"]
# alldata["diff3"] = alldata["r"] - alldata["dered_i"]
# alldata["diff4"] = alldata["i"] - alldata["dered_i"]
# alldata["diff"] = alldata["z"] - alldata["dered_z"]

# alldata["nObserve"] = np.log1p(alldata["nObserve"])
# alldata["nDetect"] = np.log1p(alldata["nDetect"])


alldata
# Out:
#            id          u          g          r          i          z  \
# 0           0  23.263956  20.336773  19.009500  17.672439  16.939607
# 1           1  15.052147  14.061969  13.452418  13.268450  13.168941
# 2           2  16.786385  15.825426  15.536318  15.393535  15.350032
# 3           3  25.660638  21.188727  20.221158  19.894949  19.634649
# 4           4  24.453429  20.699170  19.042368  18.324152  17.982649
# ...       ...        ...        ...        ...        ...        ...
# 79995  399995  19.673388  18.661662  18.270788  18.122501  18.062672
# 79996  399996  21.522869  20.728282  20.608695  21.004875  20.845799
# 79997  399997  19.399065  18.241076  18.160492  18.197753  18.201831
# 79998  399998  18.899747  17.600868  17.132878  16.822347  16.594561
# 79999  399999  20.758705  20.425247  20.536181  20.772863  20.969791
#
#        redshift   dered_u   dered_g   dered_r   dered_i   dered_z  nObserve  \
# 0     -0.000081  23.12426  20.25779  18.95512  17.63211  16.90894        18
# 1      0.004506  14.96642  14.00452  13.41139  13.23625  13.13468         1
# 2      0.000472  16.60765  15.68659  15.44004  15.32173  15.29608         2
# 3      0.000006  25.35365  20.99465  20.08727  19.79465  19.55518         4
# 4     -0.000033  23.77140  20.43384  18.86299  18.19028  17.87592        13
# ...         ...       ...       ...       ...       ...       ...       ...
# 79995 -0.000317  19.33614  18.39331  18.08600  17.98610  17.96699        17
# 79996  0.065455  21.39935  20.63992  20.54506  20.95069  20.78268         8
# 79997 -0.000842  18.91359  17.87533  17.90469  18.00426  18.04000         1
# 79998  0.042817  18.77153  17.48798  17.05567  16.76595  16.55850        17
# 79999  0.000285  20.49577  20.21810  20.39393  20.66961  20.90850         5
#
#        nDetect  airmass_u  airmass_g  airmass_r  airmass_i  airmass_z  class  \
# 0           18   1.189764   1.190681   1.188979   1.189355   1.190206    0.0
# 1            1   1.253254   1.257836   1.248762   1.250997   1.255533    1.0
# 2            2   1.022499   1.024105   1.020983   1.021730   1.023291    0.0
# 3            3   1.205399   1.206058   1.204874   1.205120   1.205712    0.0
# 4           12   1.193946   1.194285   1.193738   1.193826   1.194099    0.0
# ...        ...        ...        ...        ...        ...        ...    ...
# 79995       17   1.185843   1.186322   1.185493   1.185652   1.186067    NaN
# 79996        4   1.284956   1.290772   1.279329   1.282120   1.287838    NaN
# 79997        1   1.188475   1.188563   1.188518   1.188480   1.188503    NaN
# 79998       17   1.180429   1.181329   1.179654   1.180025   1.180862    NaN
# 79999        5   1.183152   1.177529   1.188900   1.186009   1.180324    NaN
#
#             u-g       g-r       r-i       i-z  dered_diff1  dered_diff2  \
# 0      2.927183  1.327273  1.337061  0.732833      2.86647      1.30267
# 1      0.990179  0.609551  0.183968  0.099509      0.96190      0.59313
# 2      0.960959  0.289108  0.142783  0.043503      0.92106      0.24655
# 3      4.471910  0.967569  0.326209  0.260300      4.35900      0.90738
# 4      3.754259  1.656803  0.718216  0.341503      3.33756      1.57085
# ...         ...       ...       ...       ...          ...          ...
# 79995  1.011727  0.390873  0.148287  0.059829      0.94283      0.30731
# 79996  0.794588  0.119586 -0.396179  0.159076      0.75943      0.09486
# 79997  1.157989  0.080584 -0.037262 -0.004078      1.03826     -0.02936
# 79998  1.298879  0.467991  0.310531  0.227785      1.28355      0.43231
# 79999  0.333457 -0.110934 -0.236682 -0.196928      0.27767     -0.17583
#
#        dered_diff3  dered_diff4
# 0          1.32301      0.72317
# 1          0.17514      0.10157
# 2          0.11831      0.02565
# 3          0.29262      0.23947
# 4          0.67271      0.31436
# ...            ...          ...
# 79995      0.09990      0.01911
# 79996     -0.40563      0.16801
# 79997     -0.09957     -0.03574
# 79998      0.28972      0.20745
# 79999     -0.27568     -0.23889
#
# [400000 rows x 28 columns]

# %%
sns.distplot(train["redshift"])

# %%
# binn_shift = pd.qcut(train["redshift"], 50, labels = False)
# binn_shift

# alldata["binn_shift"] = binn_shift
# alldata

# %%
# alldata["u"] = alldata["u"]+17.7
# alldata["g"] = alldata["g"]+52
# alldata["r"] = alldata["r"]+5.5
# alldata["z"] = alldata["z"]+39.6

# alldata[["u","g","r","i","z"]] = alldata[["u","g","r","i","z"]].apply(np.log1p)
# alldata

# %%
alldata2 = alldata.drop(["id","class","airmass_u","airmass_g","airmass_r","airmass_i","airmass_z"], axis=1)
# alldata2 = alldata2.drop(["u","g","r","i","z"], axis=1)

alldata2
# Out:
#                u          g          r          i          z  redshift  \
# 0      23.263956  20.336773  19.009500  17.672439  16.939607 -0.000081
# 1      15.052147  14.061969  13.452418  13.268450  13.168941  0.004506
# 2      16.786385  15.825426  15.536318  15.393535  15.350032  0.000472
# 3      25.660638  21.188727  20.221158  19.894949  19.634649  0.000006
# 4      24.453429  20.699170  19.042368  18.324152  17.982649 -0.000033
# ...          ...        ...        ...        ...        ...       ...
# 79995  19.673388  18.661662  18.270788  18.122501  18.062672 -0.000317
# 79996  21.522869  20.728282  20.608695  21.004875  20.845799  0.065455
# 79997  19.399065  18.241076  18.160492  18.197753  18.201831 -0.000842
# 79998  18.899747  17.600868  17.132878  16.822347  16.594561  0.042817
# 79999  20.758705  20.425247  20.536181  20.772863  20.969791  0.000285
#
#         dered_u   dered_g   dered_r   dered_i   dered_z  nObserve  nDetect  \
# 0      23.12426  20.25779  18.95512  17.63211  16.90894        18       18
# 1      14.96642  14.00452  13.41139  13.23625  13.13468         1        1
# 2      16.60765  15.68659  15.44004  15.32173  15.29608         2        2
# 3      25.35365  20.99465  20.08727  19.79465  19.55518         4        3
# 4      23.77140  20.43384  18.86299  18.19028  17.87592        13       12
# ...         ...       ...       ...       ...       ...       ...      ...
# 79995  19.33614  18.39331  18.08600  17.98610  17.96699        17       17
# 79996  21.39935  20.63992  20.54506  20.95069  20.78268         8        4
# 79997  18.91359  17.87533  17.90469  18.00426  18.04000         1        1
# 79998  18.77153  17.48798  17.05567  16.76595  16.55850        17       17
# 79999  20.49577  20.21810  20.39393  20.66961  20.90850         5        5
#
#             u-g       g-r       r-i       i-z  dered_diff1  dered_diff2  \
# 0      2.927183  1.327273  1.337061  0.732833      2.86647      1.30267
# 1      0.990179  0.609551  0.183968  0.099509      0.96190      0.59313
# 2      0.960959  0.289108  0.142783  0.043503      0.92106      0.24655
# 3      4.471910  0.967569  0.326209  0.260300      4.35900      0.90738
# 4      3.754259  1.656803  0.718216  0.341503      3.33756      1.57085
# ...         ...       ...       ...       ...          ...          ...
# 79995  1.011727  0.390873  0.148287  0.059829      0.94283      0.30731
# 79996  0.794588  0.119586 -0.396179  0.159076      0.75943      0.09486
# 79997  1.157989  0.080584 -0.037262 -0.004078      1.03826     -0.02936
# 79998  1.298879  0.467991  0.310531  0.227785      1.28355      0.43231
# 79999  0.333457 -0.110934 -0.236682 -0.196928      0.27767     -0.17583
#
#        dered_diff3  dered_diff4
# 0          1.32301      0.72317
# 1          0.17514      0.10157
# 2          0.11831      0.02565
# 3          0.29262      0.23947
# 4          0.67271      0.31436
# ...            ...          ...
# 79995      0.09990      0.01911
# 79996     -0.40563      0.16801
# 79997     -0.09957     -0.03574
# 79998      0.28972      0.20745
# 79999     -0.27568     -0.23889
#
# [400000 rows x 21 columns]

# %%
train2 = alldata2[:len(train)]
test2 = alldata2[len(train):]

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report, accuracy_score

# x_train,x_valid, y_train, y_valid = train_test_split(train2, train["class"], test_size = 0.2, random_state = 42, shuffle = True,stratify = train["class"])

# hr2_accuracy_list = []

# max_depth_list = [195,200,205]
# # subsample_list = [0.6,0.7,0.8,0.9,1.0]

# def hr2_grid_search(max_depth): 
#     xgb_model = LGBMClassifier(n_estimators = 250, num_leaves=max_depth, n_jobs = -1)
#     xgb_pred = xgb_model.fit(x_train, y_train).predict(x_valid)
#     return([max_depth, accuracy_score(y_valid, xgb_pred)])
      

# for max_depth in max_depth_list:
#     hr2_accuracy_list.append(hr2_grid_search(max_depth))
    

# hr2_xgb_df = pd.DataFrame(hr2_accuracy_list, columns=['tree depth', 'accuracy'])
# print("accuracy max : "+str(hr2_xgb_df["accuracy"].argmax())+"행") 
# print(hr2_xgb_df)

# %%
# from sklearn.preprocessing import StandardScaler
# ss = StandardScaler()
# alldata2 = ss.fit_transform(alldataa2)

# %%
## randomforest모델
# rf = RandomForestClassifier(n_estimators = 400)
# rf.fit(train2,train["class"])
# rf_result = rf.predict_proba(test2)

# rf_df = pd.DataFrame(rf_result)
# rf_df.columns = ["rf1","rf2","rf3"]
# rf_df.to_csv("rf_result.csv", index = False)


## catboost모델
# ca = CatBoostClassifier(n_estimators = 2000)
# ca.fit(x_train,y_train, eval_set = (x_valid, y_valid), early_stopping_rounds = 30)


x_train, x_valid, y_train, y_valid = train_test_split(train2,train["class"], 
                                                      test_size = 0.2, 
                                                      random_state = 42, 
                                                      shuffle = True, 
                                                      stratify = train["class"])

# lgb모델
# 1554 = n_estimators = 1500, num_leaves = 200, n_jobs = -1, learning_rate = 0.01
# lgb = LGBMClassifier(n_estimators = 300, num_leaves = 200, n_jobs = -1)
# lgb.fit(x_train,y_train, eval_set = (x_valid, y_valid), early_stopping_rounds = 100)


lgb = LGBMClassifier(n_estimators = 500, n_jobs = -1, min_sample_leaf = 10)
lgb.fit(x_train,y_train, eval_set = (x_valid, y_valid), early_stopping_rounds = 100)

# 200 0.1557 -> 0.1554

# 0.1570 Base
# Out:
# [1]	valid_0's multi_logloss: 0.878127
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.790624
# [3]	valid_0's multi_logloss: 0.717543
# [4]	valid_0's multi_logloss: 0.655631
# [5]	valid_0's multi_logloss: 0.602426
# [6]	valid_0's multi_logloss: 0.556434
# [7]	valid_0's multi_logloss: 0.516411
# [8]	valid_0's multi_logloss: 0.481128
# [9]	valid_0's multi_logloss: 0.450055
# [10]	valid_0's multi_logloss: 0.422546
# [11]	valid_0's multi_logloss: 0.39824
# [12]	valid_0's multi_logloss: 0.376548
# [13]	valid_0's multi_logloss: 0.356973
# [14]	valid_0's multi_logloss: 0.339602
# [15]	valid_0's multi_logloss: 0.324137
# [16]	valid_0's multi_logloss: 0.310176
# [17]	valid_0's multi_logloss: 0.297644
# [18]	valid_0's multi_logloss: 0.286265
# [19]	valid_0's multi_logloss: 0.275829
# [20]	valid_0's multi_logloss: 0.266568
# [21]	valid_0's multi_logloss: 0.258041
# [22]	valid_0's multi_logloss: 0.250157
# [23]	valid_0's multi_logloss: 0.242987
# [24]	valid_0's multi_logloss: 0.23655
# [25]	valid_0's multi_logloss: 0.230607
# [26]	valid_0's multi_logloss: 0.225208
# [27]	valid_0's multi_logloss: 0.220309
# [28]	valid_0's multi_logloss: 0.215736
# [29]	valid_0's multi_logloss: 0.211571
# [30]	valid_0's multi_logloss: 0.207753
# [31]	valid_0's multi_logloss: 0.204315
# [32]	valid_0's multi_logloss: 0.201168
# [33]	valid_0's multi_logloss: 0.198261
# [34]	valid_0's multi_logloss: 0.195552
# [35]	valid_0's multi_logloss: 0.193089
# [36]	valid_0's multi_logloss: 0.190832
# [37]	valid_0's multi_logloss: 0.188634
# [38]	valid_0's multi_logloss: 0.186655
# [39]	valid_0's multi_logloss: 0.184913
# [40]	valid_0's multi_logloss: 0.183195
# [41]	valid_0's multi_logloss: 0.181685
# [42]	valid_0's multi_logloss: 0.180251
# [43]	valid_0's multi_logloss: 0.178962
# [44]	valid_0's multi_logloss: 0.177756
# [45]	valid_0's multi_logloss: 0.176595
# [46]	valid_0's multi_logloss: 0.175539
# [47]	valid_0's multi_logloss: 0.174614
# [48]	valid_0's multi_logloss: 0.173691
# [49]	valid_0's multi_logloss: 0.172842
# [50]	valid_0's multi_logloss: 0.172056
# [51]	valid_0's multi_logloss: 0.171277
# [52]	valid_0's multi_logloss: 0.170584
# [53]	valid_0's multi_logloss: 0.169923
# [54]	valid_0's multi_logloss: 0.169344
# [55]	valid_0's multi_logloss: 0.168779
# [56]	valid_0's multi_logloss: 0.168277
# [57]	valid_0's multi_logloss: 0.167766
# [58]	valid_0's multi_logloss: 0.16732
# [59]	valid_0's multi_logloss: 0.166868
# [60]	valid_0's multi_logloss: 0.166426
# [61]	valid_0's multi_logloss: 0.166008
# [62]	valid_0's multi_logloss: 0.165644
# [63]	valid_0's multi_logloss: 0.165295
# [64]	valid_0's multi_logloss: 0.164967
# [65]	valid_0's multi_logloss: 0.164644
# [66]	valid_0's multi_logloss: 0.164432
# [67]	valid_0's multi_logloss: 0.164126
# [68]	valid_0's multi_logloss: 0.163851
# [69]	valid_0's multi_logloss: 0.163609
# [70]	valid_0's multi_logloss: 0.163382
# [71]	valid_0's multi_logloss: 0.163098
# [72]	valid_0's multi_logloss: 0.162861
# [73]	valid_0's multi_logloss: 0.162629
# [74]	valid_0's multi_logloss: 0.162457
# [75]	valid_0's multi_logloss: 0.162295
# [76]	valid_0's multi_logloss: 0.162873
# [77]	valid_0's multi_logloss: 0.162012
# [78]	valid_0's multi_logloss: 0.161861
# [79]	valid_0's multi_logloss: 0.161705
# [80]	valid_0's multi_logloss: 0.161734
# [81]	valid_0's multi_logloss: 0.162533
# [82]	valid_0's multi_logloss: 0.161976
# [83]	valid_0's multi_logloss: 0.161828
# [84]	valid_0's multi_logloss: 0.16173
# [85]	valid_0's multi_logloss: 0.161618
# [86]	valid_0's multi_logloss: 0.161521
# [87]	valid_0's multi_logloss: 0.161391
# [88]	valid_0's multi_logloss: 0.161271
# [89]	valid_0's multi_logloss: 0.161189
# [90]	valid_0's multi_logloss: 0.161094
# [91]	valid_0's multi_logloss: 0.160953
# [92]	valid_0's multi_logloss: 0.160837
# [93]	valid_0's multi_logloss: 0.160722
# [94]	valid_0's multi_logloss: 0.160662
# [95]	valid_0's multi_logloss: 0.160591
# [96]	valid_0's multi_logloss: 0.16052
# [97]	valid_0's multi_logloss: 0.160478
# [98]	valid_0's multi_logloss: 0.160387
# [99]	valid_0's multi_logloss: 0.160334
# [100]	valid_0's multi_logloss: 0.160251
# [101]	valid_0's multi_logloss: 0.160176
# [102]	valid_0's multi_logloss: 0.160075
# [103]	valid_0's multi_logloss: 0.160003
# [104]	valid_0's multi_logloss: 0.159958
# [105]	valid_0's multi_logloss: 0.159907
# [106]	valid_0's multi_logloss: 0.159861
# [107]	valid_0's multi_logloss: 0.159817
# [108]	valid_0's multi_logloss: 0.159767
# [109]	valid_0's multi_logloss: 0.159707
# [110]	valid_0's multi_logloss: 0.159676
# [111]	valid_0's multi_logloss: 0.159655
# [112]	valid_0's multi_logloss: 0.159621
# [113]	valid_0's multi_logloss: 0.159547
# [114]	valid_0's multi_logloss: 0.159492
# [115]	valid_0's multi_logloss: 0.159459
# [116]	valid_0's multi_logloss: 0.159396
# [117]	valid_0's multi_logloss: 0.159367
# [118]	valid_0's multi_logloss: 0.159335
# [119]	valid_0's multi_logloss: 0.159328
# [120]	valid_0's multi_logloss: 0.15929
# [121]	valid_0's multi_logloss: 0.159259
# [122]	valid_0's multi_logloss: 0.15922
# [123]	valid_0's multi_logloss: 0.159168
# [124]	valid_0's multi_logloss: 0.159168
# [125]	valid_0's multi_logloss: 0.15912
# [126]	valid_0's multi_logloss: 0.159079
# [127]	valid_0's multi_logloss: 0.159003
# [128]	valid_0's multi_logloss: 0.158961
# [129]	valid_0's multi_logloss: 0.158913
# [130]	valid_0's multi_logloss: 0.158909
# [131]	valid_0's multi_logloss: 0.158856
# [132]	valid_0's multi_logloss: 0.15882
# [133]	valid_0's multi_logloss: 0.158808
# [134]	valid_0's multi_logloss: 0.158774
# [135]	valid_0's multi_logloss: 0.158738
# [136]	valid_0's multi_logloss: 0.158696
# [137]	valid_0's multi_logloss: 0.158665
# [138]	valid_0's multi_logloss: 0.15862
# [139]	valid_0's multi_logloss: 0.158591
# [140]	valid_0's multi_logloss: 0.158566
# [141]	valid_0's multi_logloss: 0.158537
# [142]	valid_0's multi_logloss: 0.158517
# [143]	valid_0's multi_logloss: 0.158502
# [144]	valid_0's multi_logloss: 0.158473
# [145]	valid_0's multi_logloss: 0.158444
# [146]	valid_0's multi_logloss: 0.158445
# [147]	valid_0's multi_logloss: 0.158428
# [148]	valid_0's multi_logloss: 0.158408
# [149]	valid_0's multi_logloss: 0.158395
# [150]	valid_0's multi_logloss: 0.158381
# [151]	valid_0's multi_logloss: 0.158365
# [152]	valid_0's multi_logloss: 0.158324
# [153]	valid_0's multi_logloss: 0.158305
# [154]	valid_0's multi_logloss: 0.158285
# [155]	valid_0's multi_logloss: 0.158265
# [156]	valid_0's multi_logloss: 0.158247
# [157]	valid_0's multi_logloss: 0.158243
# [158]	valid_0's multi_logloss: 0.158206
# [159]	valid_0's multi_logloss: 0.158163
# [160]	valid_0's multi_logloss: 0.158145
# [161]	valid_0's multi_logloss: 0.158131
# [162]	valid_0's multi_logloss: 0.158103
# [163]	valid_0's multi_logloss: 0.158089
# [164]	valid_0's multi_logloss: 0.158083
# [165]	valid_0's multi_logloss: 0.158073
# [166]	valid_0's multi_logloss: 0.158075
# [167]	valid_0's multi_logloss: 0.158072
# [168]	valid_0's multi_logloss: 0.158069
# [169]	valid_0's multi_logloss: 0.158049
# [170]	valid_0's multi_logloss: 0.158028
# [171]	valid_0's multi_logloss: 0.158003
# [172]	valid_0's multi_logloss: 0.157998
# [173]	valid_0's multi_logloss: 0.15798
# [174]	valid_0's multi_logloss: 0.157931
# [175]	valid_0's multi_logloss: 0.157941
# [176]	valid_0's multi_logloss: 0.157926
# [177]	valid_0's multi_logloss: 0.157906
# [178]	valid_0's multi_logloss: 0.157915
# [179]	valid_0's multi_logloss: 0.157907
# [180]	valid_0's multi_logloss: 0.157879
# [181]	valid_0's multi_logloss: 0.157846
# [182]	valid_0's multi_logloss: 0.157838
# [183]	valid_0's multi_logloss: 0.157819
# [184]	valid_0's multi_logloss: 0.157841
# [185]	valid_0's multi_logloss: 0.157827
# [186]	valid_0's multi_logloss: 0.157802
# [187]	valid_0's multi_logloss: 0.157794
# [188]	valid_0's multi_logloss: 0.157785
# [189]	valid_0's multi_logloss: 0.157781
# [190]	valid_0's multi_logloss: 0.157791
# [191]	valid_0's multi_logloss: 0.157792
# [192]	valid_0's multi_logloss: 0.157776
# [193]	valid_0's multi_logloss: 0.157765
# [194]	valid_0's multi_logloss: 0.157753
# [195]	valid_0's multi_logloss: 0.157753
# [196]	valid_0's multi_logloss: 0.157736
# [197]	valid_0's multi_logloss: 0.157753
# [198]	valid_0's multi_logloss: 0.157751
# [199]	valid_0's multi_logloss: 0.157746
# [200]	valid_0's multi_logloss: 0.157716
# [201]	valid_0's multi_logloss: 0.157711
# [202]	valid_0's multi_logloss: 0.157699
# [203]	valid_0's multi_logloss: 0.157679
# [204]	valid_0's multi_logloss: 0.157684
# [205]	valid_0's multi_logloss: 0.157649
# [206]	valid_0's multi_logloss: 0.157647
# [207]	valid_0's multi_logloss: 0.157657
# [208]	valid_0's multi_logloss: 0.157642
# [209]	valid_0's multi_logloss: 0.157642
# [210]	valid_0's multi_logloss: 0.157633
# [211]	valid_0's multi_logloss: 0.157622
# [212]	valid_0's multi_logloss: 0.157619
# [213]	valid_0's multi_logloss: 0.157621
# [214]	valid_0's multi_logloss: 0.157624
# [215]	valid_0's multi_logloss: 0.157624
# [216]	valid_0's multi_logloss: 0.157623
# [217]	valid_0's multi_logloss: 0.157607
# [218]	valid_0's multi_logloss: 0.157609
# [219]	valid_0's multi_logloss: 0.15761
# [220]	valid_0's multi_logloss: 0.1576
# [221]	valid_0's multi_logloss: 0.157607
# [222]	valid_0's multi_logloss: 0.157605
# [223]	valid_0's multi_logloss: 0.157597
# [224]	valid_0's multi_logloss: 0.1576
# [225]	valid_0's multi_logloss: 0.157599
# [226]	valid_0's multi_logloss: 0.157595
# [227]	valid_0's multi_logloss: 0.157595
# [228]	valid_0's multi_logloss: 0.157591
# [229]	valid_0's multi_logloss: 0.157595
# [230]	valid_0's multi_logloss: 0.157577
# [231]	valid_0's multi_logloss: 0.15758
# [232]	valid_0's multi_logloss: 0.157552
# [233]	valid_0's multi_logloss: 0.157535
# [234]	valid_0's multi_logloss: 0.157524
# [235]	valid_0's multi_logloss: 0.157505
# [236]	valid_0's multi_logloss: 0.157506
# [237]	valid_0's multi_logloss: 0.157504
# [238]	valid_0's multi_logloss: 0.157504
# [239]	valid_0's multi_logloss: 0.1575
# [240]	valid_0's multi_logloss: 0.157495
# [241]	valid_0's multi_logloss: 0.157489
# [242]	valid_0's multi_logloss: 0.157463
# [243]	valid_0's multi_logloss: 0.157456
# [244]	valid_0's multi_logloss: 0.157472
# [245]	valid_0's multi_logloss: 0.157473
# [246]	valid_0's multi_logloss: 0.157464
# [247]	valid_0's multi_logloss: 0.157452
# [248]	valid_0's multi_logloss: 0.157442
# [249]	valid_0's multi_logloss: 0.157427
# [250]	valid_0's multi_logloss: 0.157421
# [251]	valid_0's multi_logloss: 0.157426
# [252]	valid_0's multi_logloss: 0.157417
# [253]	valid_0's multi_logloss: 0.157408
# [254]	valid_0's multi_logloss: 0.157415
# [255]	valid_0's multi_logloss: 0.157389
# [256]	valid_0's multi_logloss: 0.157381
# [257]	valid_0's multi_logloss: 0.157359
# [258]	valid_0's multi_logloss: 0.15735
# [259]	valid_0's multi_logloss: 0.157356
# [260]	valid_0's multi_logloss: 0.157359
# [261]	valid_0's multi_logloss: 0.157349
# [262]	valid_0's multi_logloss: 0.157341
# [263]	valid_0's multi_logloss: 0.157321
# [264]	valid_0's multi_logloss: 0.157316
# [265]	valid_0's multi_logloss: 0.157305
# [266]	valid_0's multi_logloss: 0.15731
# [267]	valid_0's multi_logloss: 0.157312
# [268]	valid_0's multi_logloss: 0.157297
# [269]	valid_0's multi_logloss: 0.157298
# [270]	valid_0's multi_logloss: 0.157289
# [271]	valid_0's multi_logloss: 0.157284
# [272]	valid_0's multi_logloss: 0.15727
# [273]	valid_0's multi_logloss: 0.157261
# [274]	valid_0's multi_logloss: 0.15725
# [275]	valid_0's multi_logloss: 0.15723
# [276]	valid_0's multi_logloss: 0.157229
# [277]	valid_0's multi_logloss: 0.15722
# [278]	valid_0's multi_logloss: 0.157214
# [279]	valid_0's multi_logloss: 0.157206
# [280]	valid_0's multi_logloss: 0.157204
# [281]	valid_0's multi_logloss: 0.15719
# [282]	valid_0's multi_logloss: 0.157163
# [283]	valid_0's multi_logloss: 0.157167
# [284]	valid_0's multi_logloss: 0.157165
# [285]	valid_0's multi_logloss: 0.157152
# [286]	valid_0's multi_logloss: 0.157145
# [287]	valid_0's multi_logloss: 0.157128
# [288]	valid_0's multi_logloss: 0.157116
# [289]	valid_0's multi_logloss: 0.157115
# [290]	valid_0's multi_logloss: 0.15711
# [291]	valid_0's multi_logloss: 0.157125
# [292]	valid_0's multi_logloss: 0.157129
# [293]	valid_0's multi_logloss: 0.157125
# [294]	valid_0's multi_logloss: 0.157115
# [295]	valid_0's multi_logloss: 0.15711
# [296]	valid_0's multi_logloss: 0.157097
# [297]	valid_0's multi_logloss: 0.157101
# [298]	valid_0's multi_logloss: 0.157106
# [299]	valid_0's multi_logloss: 0.157118
# [300]	valid_0's multi_logloss: 0.157113
# [301]	valid_0's multi_logloss: 0.157113
# [302]	valid_0's multi_logloss: 0.1571
# [303]	valid_0's multi_logloss: 0.157111
# [304]	valid_0's multi_logloss: 0.157107
# [305]	valid_0's multi_logloss: 0.157118
# [306]	valid_0's multi_logloss: 0.157117
# [307]	valid_0's multi_logloss: 0.157115
# [308]	valid_0's multi_logloss: 0.157125
# [309]	valid_0's multi_logloss: 0.157111
# [310]	valid_0's multi_logloss: 0.157115
# [311]	valid_0's multi_logloss: 0.157098
# [312]	valid_0's multi_logloss: 0.157093
# [313]	valid_0's multi_logloss: 0.157095
# [314]	valid_0's multi_logloss: 0.157095
# [315]	valid_0's multi_logloss: 0.157104
# [316]	valid_0's multi_logloss: 0.157086
# [317]	valid_0's multi_logloss: 0.157082
# [318]	valid_0's multi_logloss: 0.157076
# [319]	valid_0's multi_logloss: 0.157088
# [320]	valid_0's multi_logloss: 0.15708
# [321]	valid_0's multi_logloss: 0.157079
# [322]	valid_0's multi_logloss: 0.157082
# [323]	valid_0's multi_logloss: 0.15709
# [324]	valid_0's multi_logloss: 0.157085
# [325]	valid_0's multi_logloss: 0.157091
# [326]	valid_0's multi_logloss: 0.157089
# [327]	valid_0's multi_logloss: 0.157075
# [328]	valid_0's multi_logloss: 0.157103
# [329]	valid_0's multi_logloss: 0.157094
# [330]	valid_0's multi_logloss: 0.15709
# [331]	valid_0's multi_logloss: 0.157087
# [332]	valid_0's multi_logloss: 0.157082
# [333]	valid_0's multi_logloss: 0.157087
# [334]	valid_0's multi_logloss: 0.157083
# [335]	valid_0's multi_logloss: 0.157102
# [336]	valid_0's multi_logloss: 0.157104
# [337]	valid_0's multi_logloss: 0.157105
# [338]	valid_0's multi_logloss: 0.157096
# [339]	valid_0's multi_logloss: 0.157104
# [340]	valid_0's multi_logloss: 0.157099
# [341]	valid_0's multi_logloss: 0.157098
# [342]	valid_0's multi_logloss: 0.157102
# [343]	valid_0's multi_logloss: 0.157104
# [344]	valid_0's multi_logloss: 0.157098
# [345]	valid_0's multi_logloss: 0.157101
# [346]	valid_0's multi_logloss: 0.157107
# [347]	valid_0's multi_logloss: 0.157098
# [348]	valid_0's multi_logloss: 0.157101
# [349]	valid_0's multi_logloss: 0.157085
# [350]	valid_0's multi_logloss: 0.157085
# [351]	valid_0's multi_logloss: 0.157094
# [352]	valid_0's multi_logloss: 0.157098
# [353]	valid_0's multi_logloss: 0.157101
# [354]	valid_0's multi_logloss: 0.157092
# [355]	valid_0's multi_logloss: 0.1571
# [356]	valid_0's multi_logloss: 0.157109
# [357]	valid_0's multi_logloss: 0.157103
# [358]	valid_0's multi_logloss: 0.157103
# [359]	valid_0's multi_logloss: 0.157089
# [360]	valid_0's multi_logloss: 0.157086
# [361]	valid_0's multi_logloss: 0.157087
# [362]	valid_0's multi_logloss: 0.157091
# [363]	valid_0's multi_logloss: 0.157109
# [364]	valid_0's multi_logloss: 0.157091
# [365]	valid_0's multi_logloss: 0.1571
# [366]	valid_0's multi_logloss: 0.157096
# [367]	valid_0's multi_logloss: 0.157099
# [368]	valid_0's multi_logloss: 0.157102
# [369]	valid_0's multi_logloss: 0.157108
# [370]	valid_0's multi_logloss: 0.157117
# [371]	valid_0's multi_logloss: 0.157094
# [372]	valid_0's multi_logloss: 0.157082
# [373]	valid_0's multi_logloss: 0.157064
# [374]	valid_0's multi_logloss: 0.157072
# [375]	valid_0's multi_logloss: 0.157058
# [376]	valid_0's multi_logloss: 0.157049
# [377]	valid_0's multi_logloss: 0.157042
# [378]	valid_0's multi_logloss: 0.157028
# [379]	valid_0's multi_logloss: 0.15702
# [380]	valid_0's multi_logloss: 0.157038
# [381]	valid_0's multi_logloss: 0.157045
# [382]	valid_0's multi_logloss: 0.157056
# [383]	valid_0's multi_logloss: 0.157065
# [384]	valid_0's multi_logloss: 0.157049
# [385]	valid_0's multi_logloss: 0.157065
# [386]	valid_0's multi_logloss: 0.157059
# [387]	valid_0's multi_logloss: 0.157042
# [388]	valid_0's multi_logloss: 0.157024
# [389]	valid_0's multi_logloss: 0.15703
# [390]	valid_0's multi_logloss: 0.157033
# [391]	valid_0's multi_logloss: 0.157034
# [392]	valid_0's multi_logloss: 0.157029
# [393]	valid_0's multi_logloss: 0.157019
# [394]	valid_0's multi_logloss: 0.157019
# [395]	valid_0's multi_logloss: 0.157029
# [396]	valid_0's multi_logloss: 0.157035
# [397]	valid_0's multi_logloss: 0.15704
# [398]	valid_0's multi_logloss: 0.15705
# [399]	valid_0's multi_logloss: 0.157031
# [400]	valid_0's multi_logloss: 0.157034
# [401]	valid_0's multi_logloss: 0.157037
# [402]	valid_0's multi_logloss: 0.157041
# [403]	valid_0's multi_logloss: 0.157028
# [404]	valid_0's multi_logloss: 0.157038
# [405]	valid_0's multi_logloss: 0.157022
# [406]	valid_0's multi_logloss: 0.157023
# [407]	valid_0's multi_logloss: 0.157028
# [408]	valid_0's multi_logloss: 0.157027
# [409]	valid_0's multi_logloss: 0.157031
# [410]	valid_0's multi_logloss: 0.157031
# [411]	valid_0's multi_logloss: 0.157031
# [412]	valid_0's multi_logloss: 0.157032
# [413]	valid_0's multi_logloss: 0.157037
# [414]	valid_0's multi_logloss: 0.157031
# [415]	valid_0's multi_logloss: 0.157029
# [416]	valid_0's multi_logloss: 0.157034
# [417]	valid_0's multi_logloss: 0.157041
# [418]	valid_0's multi_logloss: 0.157048
# [419]	valid_0's multi_logloss: 0.157042
# [420]	valid_0's multi_logloss: 0.157054
# [421]	valid_0's multi_logloss: 0.157058
# [422]	valid_0's multi_logloss: 0.157061
# [423]	valid_0's multi_logloss: 0.15706
# [424]	valid_0's multi_logloss: 0.157073
# [425]	valid_0's multi_logloss: 0.157069
# [426]	valid_0's multi_logloss: 0.157065
# [427]	valid_0's multi_logloss: 0.157069
# [428]	valid_0's multi_logloss: 0.157064
# [429]	valid_0's multi_logloss: 0.157051
# [430]	valid_0's multi_logloss: 0.157052
# [431]	valid_0's multi_logloss: 0.157048
# [432]	valid_0's multi_logloss: 0.157049
# [433]	valid_0's multi_logloss: 0.157042
# [434]	valid_0's multi_logloss: 0.157046
# [435]	valid_0's multi_logloss: 0.157058
# [436]	valid_0's multi_logloss: 0.15705
# [437]	valid_0's multi_logloss: 0.157051
# [438]	valid_0's multi_logloss: 0.157054
# [439]	valid_0's multi_logloss: 0.15707
# [440]	valid_0's multi_logloss: 0.157074
# [441]	valid_0's multi_logloss: 0.15708
# [442]	valid_0's multi_logloss: 0.157075
# [443]	valid_0's multi_logloss: 0.157077
# [444]	valid_0's multi_logloss: 0.157092
# [445]	valid_0's multi_logloss: 0.157089
# [446]	valid_0's multi_logloss: 0.157084
# [447]	valid_0's multi_logloss: 0.157093
# [448]	valid_0's multi_logloss: 0.157095
# [449]	valid_0's multi_logloss: 0.157107
# [450]	valid_0's multi_logloss: 0.157111
# [451]	valid_0's multi_logloss: 0.1571
# [452]	valid_0's multi_logloss: 0.157107
# [453]	valid_0's multi_logloss: 0.157113
# [454]	valid_0's multi_logloss: 0.157106
# [455]	valid_0's multi_logloss: 0.157116
# [456]	valid_0's multi_logloss: 0.157106
# [457]	valid_0's multi_logloss: 0.157109
# [458]	valid_0's multi_logloss: 0.157114
# [459]	valid_0's multi_logloss: 0.157117
# [460]	valid_0's multi_logloss: 0.157103
# [461]	valid_0's multi_logloss: 0.157104
# [462]	valid_0's multi_logloss: 0.157113
# [463]	valid_0's multi_logloss: 0.157114
# [464]	valid_0's multi_logloss: 0.157111
# [465]	valid_0's multi_logloss: 0.157111
# [466]	valid_0's multi_logloss: 0.157115
# [467]	valid_0's multi_logloss: 0.157117
# [468]	valid_0's multi_logloss: 0.157124
# [469]	valid_0's multi_logloss: 0.157135
# [470]	valid_0's multi_logloss: 0.157143
# [471]	valid_0's multi_logloss: 0.157128
# [472]	valid_0's multi_logloss: 0.157131
# [473]	valid_0's multi_logloss: 0.157121
# [474]	valid_0's multi_logloss: 0.157114
# [475]	valid_0's multi_logloss: 0.157118
# [476]	valid_0's multi_logloss: 0.157128
# [477]	valid_0's multi_logloss: 0.157129
# [478]	valid_0's multi_logloss: 0.157136
# [479]	valid_0's multi_logloss: 0.157145
# [480]	valid_0's multi_logloss: 0.157146
# [481]	valid_0's multi_logloss: 0.157147
# [482]	valid_0's multi_logloss: 0.157159
# [483]	valid_0's multi_logloss: 0.157156
# [484]	valid_0's multi_logloss: 0.15716
# [485]	valid_0's multi_logloss: 0.157164
# [486]	valid_0's multi_logloss: 0.157183
# [487]	valid_0's multi_logloss: 0.157177
# [488]	valid_0's multi_logloss: 0.157194
# [489]	valid_0's multi_logloss: 0.157189
# [490]	valid_0's multi_logloss: 0.157205
# [491]	valid_0's multi_logloss: 0.157206
# [492]	valid_0's multi_logloss: 0.157206
# [493]	valid_0's multi_logloss: 0.157205
# [494]	valid_0's multi_logloss: 0.15722
# Early stopping, best iteration is:
# [394]	valid_0's multi_logloss: 0.157019
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_sample_leaf=10,
#                min_split_gain=0.0, n_estimators=500, n_jobs=-1, num_leaves=31,
#                objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
# #####  Kfold 제출용 
# sfk = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)
# result = 0

# for i,j in sfk.split(train2,train["class"]):
#     x_train = train2.iloc[i]
#     x_valid = train2.iloc[j]
#     y_train = train["class"].iloc[i]
#     y_valid = train["class"].iloc[j]

#     lgb = LGBMClassifier(n_estimators = 300, num_leaves = 200, n_jobs = -1)
#     lgb.fit(x_train,y_train, eval_set = (x_valid, y_valid), early_stopping_rounds = 150)
#     result += lgb.predict_proba(test2)/10
    
# lgb_result = pd.DataFrame(result)
# lgb_result.columns = ["lgb1","lgb2","lgb3"]
# lgb_result.to_csv("lgb_result.csv", index = False)

# %%
# print(accuracy_score(np.array(y_valid).astype(int),result.argmax(1)))
# confusion_matrix(np.array(y_valid).astype(int),result.argmax(1))

# %%
sub = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\sample_submission.csv")
sub
# Out:
#            id  class
# 0      320000      0
# 1      320001      0
# 2      320002      0
# 3      320003      0
# 4      320004      0
# ...       ...    ...
# 79995  399995      0
# 79996  399996      0
# 79997  399997      0
# 79998  399998      0
# 79999  399999      0
#
# [80000 rows x 2 columns]

# %%
sub["class"] = result.argmax(1)
sub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-210-6d382cbd0155> in <module>
# ----> 1 sub["class"] = result.argmax(1)
#       2 sub
#
# NameError: name 'result' is not defined

# %%
sub.to_csv("dk_dacon.csv", index=False)

# %%
pd.Series(lgb.feature_importances_, index = train2.columns).sort_values(ascending = False).reset_index()
