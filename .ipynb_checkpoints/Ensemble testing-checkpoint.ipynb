# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (20,12)

def to_array(result):
    final_result = np.array(result)
    return final_result

# %% [markdown]
# # 로지스틱 0.851

# %%
logis = pd.read_csv("logistic_proba.csv")
logis.head()
# Out:
#           0         1         2
# 0  0.020951  0.198993  0.780056
# 1  0.952938  0.021373  0.025689
# 2  0.032654  0.118113  0.849233
# 3  0.509159  0.180809  0.310032
# 4  0.064765  0.141426  0.793810

# %% [markdown]
# # 릿지 0.6734

# %%
ridge = pd.read_csv("ridge_result.csv")
ridge.columns = ["0"]
ridge.head()
# Out:
#    0
# 0  2
# 1  0
# 2  2
# 3  2
# 4  2

# %% [markdown]
# # 랜포 0.93405

# %%
ranfo = pd.read_csv("rf_result.csv")
ranfo.head()
# Out:
#      0         1         2
# 0  0.0  0.149472  0.850528
# 1  1.0  0.000000  0.000000
# 2  0.0  0.050683  0.949317
# 3  1.0  0.000000  0.000000
# 4  0.0  0.075345  0.924655

# %% [markdown]
# # LGBM 0.9352

# %%
lgb = pd.read_csv("lgb_result.csv")
lgb.columns = ["0","1","2"]
lgb.head()
# Out:
#           0         1         2
# 0  0.000173  0.197936  0.801891
# 1  0.999958  0.000029  0.000013
# 2  0.000139  0.052725  0.947136
# 3  0.999962  0.000018  0.000020
# 4  0.000104  0.044596  0.955300

# %% [markdown]
# # XGB 0.93645

# %%
xgb = pd.read_csv("xgb_result.csv")
xgb.head()

# pd.DataFrame(np.array(xgb).argmax(1)).iloc[:,0].value_counts()
# Out:
#           0         1         2
# 0  0.001623  0.160574  0.837803
# 1  0.999298  0.000456  0.000246
# 2  0.001275  0.057803  0.940922
# 3  0.998936  0.000535  0.000529
# 4  0.001107  0.040495  0.958398

# %%
# ridge
# xgb_df = pd.DataFrame(np.array(xgb).argmax(1))
# rf_df = pd.DataFrame(np.array(ranfo).argmax(1))
# logi_df = pd.DataFrame(np.array(logis).argmax(1))
# lgb_df = pd.DataFrame(np.array(lgb).argmax(1))

# x_train = pd.concat([xgb_df,rf_df,lgb_df,logi_df], axis=1)
# x_train

# %%
# rf, xgb, ,lgb, cat
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
train = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\train.csv")
test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\test.csv")

lgb_stack = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\stack3.csv")
lgb_stack.columns = ["lgb0","lgb1","lgb2"]
rf_stack = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\stack1.csv")
rf_stack.columns = ["rf0","rf1","rf2"]
xgb_stack = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\stack2.csv")
xgb_stack.columns = ["xgb0","xgb1","xgb2"]
logis_stack = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\stack5.csv")
logis_stack.columns = ["logi0","logi1","logi2"]
ridge_stack = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\stack4.csv")


rf_test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\rf_test_stack.csv")
rf_test.columns = ["lgb0","lgb1","lgb2"]
xgb_test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\xgb_test_stack.csv")
xgb_test.columns = ["rf0","rf1","rf2"]
lgb_test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\lgb_test_stack.csv")
lgb_test.columns = ["xgb0","xgb1","xgb2"]
lr_test = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\lr_test_stack.csv")
lr_test.columns = ["logi0","logi1","logi2"]


x_train = pd.concat([lgb_stack,rf_stack,xgb_stack,logis_stack], axis=1)
x_test = pd.concat([rf_test,xgb_test,lgb_test,lr_test], axis=1)
display(x_train.head(),x_test.head())

sfk = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)
# result = 0

# for i,j in sfk.split(x_train,train["class"]):
#     x_trn = x_train.iloc[i]
#     x_val = x_train.iloc[j]
#     y_trn = train["class"].iloc[i]
#     y_val = train["class"].iloc[j]

#     lgb = LGBMClassifier(objective='multiclass',
#                      n_estimators = 300, 
#                      num_leaves=64,
#                      n_jobs = 3, 
#                      min_child_samples = 10,
#                      random_state=42
#                     )
    
#     lgb.fit(x_trn,y_trn, eval_set = (x_val, y_val), early_stopping_rounds = 10)
#     result += lgb.predict_proba(x_test)/10


# rf = LGBMClassifier()
# rf.fit(x_train,train["class"])
# result = rf.predict_proba(x_test)
# result

# xgb = XGBClassifier()
# lgb = LGBMClassifier()
# cat = CatBoostClassifier()
# Out:
#        lgb0      lgb1      lgb2       rf0       rf1       rf2      xgb0  \
# 0  0.999991  0.000003  0.000006  1.000000  0.000000  0.000000  0.999988
# 1  0.003018  0.580298  0.416684  0.001512  0.572536  0.425952  0.064112
# 2  0.999533  0.000362  0.000106  1.000000  0.000000  0.000000  0.997470
# 3  0.999966  0.000011  0.000023  1.000000  0.000000  0.000000  0.999967
# 4  0.999967  0.000007  0.000026  1.000000  0.000000  0.000000  0.999972
#
#        xgb1      xgb2         logi0         logi1         logi2
# 0  0.000006  0.000006  9.999998e-01  1.234831e-07  8.034079e-08
# 1  0.637455  0.298434  1.434696e-14  5.936954e-04  9.994063e-01
# 2  0.002111  0.000419  3.637988e-08  8.147481e-03  9.918525e-01
# 3  0.000014  0.000019  1.000000e+00  7.717517e-12  1.071981e-12
# 4  0.000007  0.000021  1.000000e+00  1.013565e-08  4.787497e-09
#    lgb0      lgb1      lgb2       rf0       rf1       rf2      xgb0      xgb1  \
# ...

# %%
def get_stacking(model, x_train, y_train, x_test, n_folds = 10):
    kfold = StratifiedKFold(n_splits = n_folds, random_state = 42, shuffle = True)
    
    train_fold_predict = np.zeros((x_train.shape[0],1))
    
    test_predict = np.zeros((x_test.shape[0], n_folds))
    print("model : ", model.__class__.__name__)
    
    for cnt, (i,j) in enumerate(kfold.split(x_train)):
        x_train_ = x_train[i]
        y_train_ = y_train[i]
        x_validation = x_train[j]
        
        model.fit(x_train_, y_train_)
        
        train_fold_predict[j,:] = model.predict(x_validation).reshape(-1,1)
        
        test_predict[:,cnt] = model.predict(x_test)
        
    test_predict_mean = np.mean(test_predict, axis=1).reshape(-1,1)
    
    return train_fold_predict, test_predict_mean

# %%
# cv = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)
# p_val = np.zeros((trn.shape[0], 3))
# p_tst = np.zeros((tst.shape[0], 3))

# for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
#     print(f'training model for CV #{i}')
#     clf = lgb.LGBMClassifier(objective='multiclass',
#                              n_estimators=1000,
#                              num_leaves=64,
#                              learning_rate=0.1,
#                              min_child_samples=10,
#                              subsample=.5,
#                              subsample_freq=1,
#                              colsample_bytree=.8,
#                              random_state=seed,
#                              n_jobs=-1)
#     clf.fit(trn[i_trn], y[i_trn],
#             eval_set=[(trn[i_val], y[i_val])],
#             eval_metric='multiclass',
#             early_stopping_rounds=10)
    
#     p_val[i_val, :] = clf.predict_proba(trn[i_val])
#     p_tst += clf.predict_proba(tst) / 10

# %%
# from sklearn.linear_model import LogisticRegression

# cv = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)
# p_val = np.zeros((x_train.shape[0], 3))
# p_tst = np.zeros((x_test.shape[0], 3))

# for i, (i_trn, i_val) in enumerate(cv.split(x_train, train["class"]), 1):
#     print(f'training model for CV #{i}')
#     clf = LogisticRegression(multi_class='multinomial')    
#     clf.fit(x_train.iloc[i_trn], train["class"].iloc[i_trn])
    
#     p_val[i_val, :] = clf.predict_proba(x_train.iloc[i_val])
#     p_tst += clf.predict_proba(x_test) / 10
# Out:
# training model for CV #1
# C:\Users\scott\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# training model for CV #2
# C:\Users\scott\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
# cv = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)
# p_val = np.zeros((x_train.shape[0], 3))
# p_tst = np.zeros((x_test.shape[0], 3))

# for i, (i_trn, i_val) in enumerate(cv.split(x_train, train["class"]), 1):
#     print(f'training model for CV #{i}')
#     clf = RandomForestClassifier(n_estimators = 200)    
#     clf.fit(x_train.iloc[i_trn], train["class"].iloc[i_trn])
    
#     p_val[i_val, :] = clf.predict_proba(x_train.iloc[i_val])
#     p_tst += clf.predict_proba(x_test) / 10
# Out:
# training model for CV #1
# training model for CV #2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-e9de2800983e> in <module>
#       6     print(f'training model for CV #{i}')
#       7     clf = RandomForestClassifier(n_estimators = 200)
# ----> 8     clf.fit(x_train.iloc[i_trn], train["class"].iloc[i_trn])
#       9
#      10     p_val[i_val, :] = clf.predict_proba(x_train.iloc[i_val])
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
# ...

# %%
# test1 = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\xgb안좋은거.csv")
# test1

# %%
# result1 = xgb*0.9 + logis*0.1 # 0.93 645 ***
# result2 = xgb*0.8 + logis*0.2 # 0.93 627
# result3 = xgb*0.7 + logis*0.3 # 0.93 54
# result4 = xgb*0.6 + logis*0.4

# result = test1*0.8 + ranfo*0.2
# result0 = xgb*0.3 + ranfo*0.7      # 93565
#result0 = xgb*0.4 + ranfo*0.6      0.93605
# result1 = xgb*0.5 + ranfo*0.5    0.9361 
# best = xgb*0.6 + ranfo*0.4 #     0.93597
# result4 = xgb*0.65 + ranfo*0.35 
# result3 = xgb*0.7 + ranfo*0.3    0.93637
# result5 = xgb*0.8 + ranfo*0.2    0.9361


# 2*xgb*ranfo/(xgb+ranfo) #조화평균 0.936025
# np.sqrt(xgb*ranfo) # 기하평균


# result1 = xgb*0.5 + lgb*0.5  
# result2 = xgb*0.6 + lgb*0.4   
# result3 = xgb*0.7 + lgb*0.3

# %%
result = to_array(result)
result
# Out:
# array([[1.67080146e-03, 1.71329394e-02, 9.81196259e-01],
#        [9.98601034e-01, 3.76568847e-04, 1.02239666e-03],
#        [1.11085112e-03, 4.90123493e-03, 9.93987914e-01],
#        ...,
#        [9.98601185e-01, 3.76417195e-04, 1.02239742e-03],
#        [6.19825516e-03, 3.62951622e-01, 6.30850122e-01],
#        [9.98601061e-01, 3.76542862e-04, 1.02239621e-03]])

# %%
sub = pd.read_csv(r"C:\Users\scott\Desktop\dankook_dacon\dataset\sample_submission.csv")
sub["class"] = p_tst.argmax(1)
sub
# Out:
#            id  class
# 0      320000      2
# 1      320001      0
# 2      320002      2
# 3      320003      0
# 4      320004      2
# ...       ...    ...
# 79995  399995      0
# 79996  399996      1
# 79997  399997      0
# 79998  399998      2
# 79999  399999      0
#
# [80000 rows x 2 columns]

# %%
sub.to_csv("ensemble.csv", index=False)
